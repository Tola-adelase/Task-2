# %% [markdown]
# ## Task 2
# In the given data set named "Task 2" .
# There are 3 groups of IDs - article level ID (articleID), Visit level ID (visitID) and User level ID (clientID).
# Every user can have multiple linked articleIDs and visitIDs.
# Every article can have  multiple linked clientIDs and visitIDs.
# Every visit can have  multiple linked articleIDs but only one clientID.
#
# Please analyze the data set using Python and present:
# * Most effective articles groups/types (you can choose your own groupings and effectiveness measure)
# * What can you suggest to the newsroom to increase the number of read pages per visit?

# %%
#Importing all packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Loading the dataset
df = pd.read_excel ('/home/axe_rhitta/Task.xlsx')
# Out:
# <ipython-input-2-307fa2a2240e>:2: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   df = pd.read_excel ('/home/axe_rhitta/Task.xlsx')

# %%
#Checking the dataframe
df
# Out:
#                                                  clientID     visitID  \
# 0                                        609764963.164611  1646110460
# 1                                        436030336.164612  1646125770
# 2                                        188469590.164532  1646174988
# 3                                        163917580.157658  1646143597
# 4                                        873862235.164609  1646095641
# ...                                                   ...         ...
# 164979                                   1933908836.16309  1646153094
# 164980                                   522358213.164615  1646153125
# 164981  amp-bphXxTTsQMTCpUkOQ9PRTY7spwo24YWDCk8S3ebtJI...  1646153635
# 164982                                   658213342.158403  1646162926
# 164983                                   1877103529.16461  1646162259
#
#        channelGrouping                                           headline  \
# ...

# %%
#Reducing the dataframe with selected columns
df1 = df[["clientID", "articleID", "visitID", "pageCategory", "channelGrouping", "wordCount"]]

# %%
#Checking the general information of the dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164984 entries, 0 to 164983
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   clientID         164963 non-null  object
#  1   articleID        164970 non-null  float64
#  2   visitID          164984 non-null  int64
#  3   pageCategory     164984 non-null  object
#  4   channelGrouping  164984 non-null  object
#  5   wordCount        164970 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.6+ MB

# %%
#Checking for the number of unique values for each column
df1.nunique()
# Out:
# clientID           136047
# articleID           11160
# visitID             66761
# pageCategory           26
# channelGrouping         7
# wordCount            1994
# dtype: int64

# %%
#Checking samples from the dataframe
df1.sample(10)
# Out:
#                                                  clientID  articleID  \
# 55645                                     75765058.164571  3578992.0
# 62657                                    523425890.164613  3588437.0
# 47903                          amp-NxzwpXNs01pY2hCHEm7Jpg  3592337.0
# 152614                                   381157615.164612  3548853.0
# 105375                                   606381992.164615  3586134.0
# 93234                                    940586361.164611  3114595.0
# 124814                                   480641310.164613  3460604.0
# 107840                                   1995028465.16461  2919234.0
# 85188                                    794197523.164615  3267963.0
# 6789    amp-Egn_-NXbxmmwEy1FaAB7zjlULEwXbV8xoyY1elE7v0...  3590569.0
#
#            visitID      pageCategory channelGrouping  wordCount
# 55645   1646137550       recommended         (Other)      570.0
# 62657   1646137571              news          Direct      579.0
# ...

# %%
df1['articleID'].value_counts()
# Out:
# 3591650.0    4949
# 3586134.0    4760
# 3580432.0    4138
# 3590569.0    4097
# 3591573.0    4067
#              ...
# 1593175.0       1
# 1432209.0       1
# 1567978.0       1
# 3408755.0       1
# 603727.0        1
# Name: articleID, Length: 11160, dtype: int64

# %%
df1['wordCount'].value_counts()
# Out:
# 172.0     4593
# 488.0     4266
# 603.0     4081
# 869.0     3879
# 513.0     3721
#           ...
# 1199.0       1
# 2708.0       1
# 1784.0       1
# 2250.0       1
# 1323.0       1
# Name: wordCount, Length: 1994, dtype: int64

# %%
#Checking the value count of the page category. 
df1['pageCategory'].value_counts()
# Out:
# news                                                                                                                  82236
# lifestyle                                                                                                             30283
# arts-and-culture                                                                                                      16133
# sport                                                                                                                  9687
# whats-on                                                                                                               4295
# heritage-and-retro                                                                                                     4165
# business                                                                                                               3404
# ...

# %% [markdown]
# ### Question 1
#
# >> #### Most effective article group/types based on page Category:
#
# News: 82236
#
# Lifestyle: 30283
#
# Arts and Culture: 16133
#
# Sport: 9687

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164984 entries, 0 to 164983
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   clientID         164963 non-null  object
#  1   articleID        164970 non-null  float64
#  2   visitID          164984 non-null  int64
#  3   pageCategory     164984 non-null  object
#  4   channelGrouping  164984 non-null  object
#  5   wordCount        164970 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.6+ MB

# %%
df2 = df[["clientID", "articleID", "visitID", "pageCategory", "author", "wordCount"]]

# %%
#Checking for the number of unique values for each column
df2.nunique()
# Out:
# clientID        136047
# articleID        11160
# visitID          66761
# pageCategory        26
# author            1029
# wordCount         1994
# dtype: int64

# %%
df3 = df2.loc[df['author'] == "by the newsroom"]

# %%
df3
# Out:
#                                                  clientID  articleID  \
# 0                                        609764963.164611  2510796.0
# 1                                        436030336.164612  2465274.0
# 2                                        188469590.164532  2463872.0
# 3                                        163917580.157658  2470582.0
# 4                                        873862235.164609  2443448.0
# ...                                                   ...        ...
# 164448                                   1327620824.16461  3098509.0
# 164641                                   1408327531.16122  1408797.0
# 164746  amp-fQ5sQ9aipVY4ybbiEamYz0orEWz80u7aygRwFp_xFj...  1415811.0
# 164794                                   188565252.164613  1608328.0
# 164795                         amp-dhvHTfJywEQJ1sBK3ByeyQ  1461307.0
#
#            visitID pageCategory           author  wordCount
# 0       1646110460         news  by the newsroom     1022.0
# ...

# %%
df3[df3.duplicated(['visitID'], keep=False)]
# Out:
#                                                  clientID  articleID  \
# 0                                        609764963.164611  2510796.0
# 8                                        1480785905.16461  1683035.0
# 12      amp-g579Fyk_NSFfSqOt_dsskiJifeUFKPs5mv-5mW-kBE...  1666440.0
# 26                                       1473910647.16461  1480858.0
# 32                             amp-0pYv-pdQYxjrUMuafR-IwA  1480858.0
# ...                                                   ...        ...
# 160631                                   340317956.164496  1474743.0
# 162743                                   1369324506.16461  1414895.0
# 162745                         amp-xpYmUzHSVVaj5Abk9cYPnw  1435271.0
# 163931                                   577085816.164615   107070.0
# 164746  amp-fQ5sQ9aipVY4ybbiEamYz0orEWz80u7aygRwFp_xFj...  1415811.0
#
#            visitID pageCategory           author  wordCount
# 0       1646110460         news  by the newsroom     1022.0
# ...

# %%
df3['pageCategory'].value_counts()
# Out:
# news                   3571
# whats-on               1455
# arts-and-culture       1300
# lifestyle               394
# sport                   360
# business                198
# regions                 168
# read-this               124
# health                  104
# education                85
# country-and-farming      79
# heritage-and-retro       50
# Name: pageCategory, dtype: int64

# %%
df3['wordCount'].value_counts()
# Out:
# 175.0     321
# 779.0     140
# 917.0     119
# 1976.0    102
# 393.0      99
#          ...
# 53.0        1
# 1043.0      1
# 1284.0      1
# 1862.0      1
# 1633.0      1
# Name: wordCount, Length: 1480, dtype: int64

# %% [markdown]
# ### Question 2
#
#
# > I would suggest newsroom should write more aritcles in page category such as art and culture, lifestyle, and sport with fewer word counts.
